# %% [markdown]
# # Materi Perkuliahan
#
# Daftar isi materi Struktur data semester 2:

# %% [markdown]
# ## 1. Stack and Queue

# %% [markdown]
#  [Materi Penjelasan Stack and Queue](Stack_And_Queue.ipynb)

# %% [markdown]
# ## 2. Infix, Prefix and Postfix Expressions

# %% [markdown]
# [Materi Penjelasan Infix, Prefix, and Postfix Expressions](Infix_Prefix_And_Postfix_Expressions.ipynb)

# %% [markdown]
# ## 3. Sorting

# %% [markdown]
# [Materi Penjelasan Sorting 1 (Bubble Sort and Selection Sort)](Sorting1.ipynb)

# %% [markdown]
# [Materi Penjelasan Sorting 2 (Insertion Sort and Quick Sort)](Sorting2.ipynb)

# %% [markdown]
# [Materi Penjelasan Sorting 3 (Merged Sort and Shell Sort)](Sorting3.ipynb)

# %% [markdown]
# ## 4. Search

# %% [markdown]
# [Materi Penjelasan Linear Search and Binary Search](Search.ipynb)

# %% [markdown]
# ## 5. Hashing

# %% [markdown]
# [Materi Penjelasan Hashing](Hashing.ipynb)

# %% [markdown]
# ## 6. Tree

# %% [markdown]
# [Materi Penjelasan Binary Tree And Parsing Binary Tree](Tree.ipynb)

# %% [markdown]
# ## 7. Deques

# %% [markdown]
# [Materi Penjelasan Deques](Deques.ipynb)

# %% [markdown]
# ## 8. Link List

# %% [markdown]
# [Materi Pemrograman Berorientasi Obyek](Pemrograman_Berorientasi_Obyek.ipynb)

# %% [markdown]
# [Materi Penjelasan Linked List](Linked_List.ipynb)
